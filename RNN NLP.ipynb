# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam


# 1. Load your data
df = pd.read_csv("consumer_complaints_copy.csv")  # replace with actual path if needed
# Out:
# C:\Users\razas\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df
# Out:
#        date_received          product                            sub_product  \
# 0         12-05-2014  Debt collection                               Mortgage
# 1         11-10-2014         Mortgage                         Other mortgage
# 2         08/26/2015         Mortgage                         Other mortgage
# 3         01/16/2014  Debt collection                               Mortgage
# 4         06/25/2015         Mortgage            Conventional fixed mortgage
# ...              ...              ...                                    ...
# 555952    01/26/2014  Debt collection               Non-federal student loan
# 555953    01/26/2016  Debt collection               Non-federal student loan
# 555954    03/31/2016  Debt collection  Other (i.e. phone, health club, etc.)
# 555955    10/13/2015  Debt collection                            Credit card
# 555956    02-03-2014  Debt collection                            Credit card
#
#                                            issue  \
# 0                Disclosure verification of debt
# 1       Loan servicing, payments, escrow account
# 2       Loan modification,collection,foreclosure
# 3                Disclosure verification of debt
# 4       Application, originator, mortgage broker
# ...                                          ...
# 555952       Improper contact or sharing of info
# 555953     Cont'd attempts collect debt not owed
# 555954           Disclosure verification of debt
# 555955           Disclosure verification of debt
# 555956        False statements or representation
#
#                                     sub_issue  \
# 0        Not given enough info to verify debt
# 1                                         NaN
# 2                                         NaN
# 3        Not given enough info to verify debt
# 4                                         NaN
# ...                                       ...
# 555952  Contacted employer after asked not to
# 555953      Debt was discharged in bankruptcy
# 555954   Not given enough info to verify debt
# 555955   Not given enough info to verify debt
# 555956   Impersonated an attorney or official
#
#                              consumer_complaint_narrative  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       My mortgage company has misrepresented themsel...
# ...                                                   ...
# 555952                                                NaN
# 555953                                                NaN
# 555954                                                NaN
# 555955                                                NaN
# 555956                                                NaN
#
#        company_public_response                                   company  \
# 0                          NaN  (Former)Shapiro, Swertfeger & Hasty, LLP
# 1                          NaN  (Former)Shapiro, Swertfeger & Hasty, LLP
# 2                          NaN  (Former)Shapiro, Swertfeger & Hasty, LLP
# 3                          NaN  (Former)Shapiro, Swertfeger & Hasty, LLP
# 4                          NaN      1st 2nd Mortgage Company Of NJ, Inc.
# ...                        ...                                       ...
# 555952                     NaN                      Zwicker & Associates
# 555953                     NaN                      Zwicker & Associates
# 555954                     NaN                      Zwicker & Associates
# 555955                     NaN                      Zwicker & Associates
# 555956                     NaN                      Zwicker & Associates
#
#        state zipcode            tags consumer_consent_provided submitted_via  \
# 0         GA   30005             NaN                       NaN      Referral
# 1         DE   19803             NaN                       NaN      Referral
# 2         GA   30014             NaN                       NaN      Referral
# 3         GA   30087             NaN                       NaN      Referral
# 4         NJ   074XX             NaN          Consent provided           Web
# ...      ...     ...             ...                       ...           ...
# 555952    MN   55428             NaN                       NaN           Web
# 555953    NJ   070XX  Older American          Consent provided           Web
# 555954    FL   33837             NaN                       NaN      Referral
# 555955    FL   33308             NaN                       NaN         Phone
# 555956    TN   38330             NaN                       NaN           Web
#
#        date_sent_to_company     company_response_to_consumer timely_response  \
# 0                12-12-2014                Untimely response              No
# 1                11/19/2014                Untimely response              No
# 2                09-08-2015                Untimely response              No
# 3                02-11-2014                Untimely response              No
# 4                07/22/2015                           Closed             Yes
# ...                     ...                              ...             ...
# 555952           01/27/2014  Closed with non-monetary relief             Yes
# 555953           02-10-2016  Closed with non-monetary relief             Yes
# 555954           04-04-2016          Closed with explanation             Yes
# 555955           10/13/2015  Closed with non-monetary relief             Yes
# 555956           02-03-2014          Closed with explanation             Yes
#
#        consumer_disputed?  complaint_id
# 0                      No       1144671
# 1                      No       1109287
# 2                      No       1536776
# 3                      No        671539
# 4                      No       1437506
# ...                   ...           ...
# 555952                 No        685904
# 555953                 No       1759548
# 555954                 No       1859430
# 555955                 No       1603745
# 555956                 No        698251
#
# [555957 rows x 18 columns]

# %%
# 2. Preprocess text
df["sub_issue"] = df["sub_issue"].fillna("")  # handle NaNs
df["text"] = df["issue"] + " " + df["sub_issue"]

# 3. Encode targets
product_encoder = LabelEncoder()
subproduct_encoder = LabelEncoder()
df["Product Encoded"] = product_encoder.fit_transform(df["product"])
df["SubProduct Encoded"] = subproduct_encoder.fit_transform(df["sub_product"])

# %%
# 4. Tokenization
tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")
tokenizer.fit_on_texts(df["text"])
sequences = tokenizer.texts_to_sequences(df["text"])
padded = pad_sequences(sequences, maxlen=100)

# 5. One-hot encode targets
product_labels = to_categorical(df["Product Encoded"])
subproduct_labels = to_categorical(df["SubProduct Encoded"])

# %%
# 6. Train/test split
X_train, X_test, y_train_prod, y_test_prod, y_train_sub, y_test_sub = train_test_split(
    padded, product_labels, subproduct_labels, test_size=0.2, random_state=42
)

# 7. Build the model
input_layer = Input(shape=(100,))
x = Embedding(input_dim=10000, output_dim=64)(input_layer)
x = LSTM(64, return_sequences=False)(x)
x = Dropout(0.5)(x)

# Output 1 - Product Category
output1 = Dense(product_labels.shape[1], activation='softmax', name="product_output")(x)

# Output 2 - Sub-Product Category
output2 = Dense(subproduct_labels.shape[1], activation='softmax', name="subproduct_output")(x)

model = Model(inputs=input_layer, outputs=[output1, output2])

# %%
# 8. Compile
model.compile(optimizer=Adam(learning_rate=0.001),
              loss={'product_output': 'categorical_crossentropy',
                    'subproduct_output': 'categorical_crossentropy'},
              metrics={'product_output': 'accuracy',
                       'subproduct_output': 'accuracy'})

# 9. Train
history = model.fit(
    X_train,
    {'product_output': y_train_prod, 'subproduct_output': y_train_sub},
    validation_split=0.2,
    epochs=10,
    batch_size=32
)
# Out:
# Epoch 1/10
# 11120/11120 [==============================] - 448s 40ms/step - loss: 1.0764 - product_output_loss: 0.0486 - subproduct_output_loss: 1.0278 - product_output_accuracy: 0.9823 - subproduct_output_accuracy: 0.6161 - val_loss: 0.9771 - val_product_output_loss: 0.0181 - val_subproduct_output_loss: 0.9590 - val_product_output_accuracy: 0.9907 - val_subproduct_output_accuracy: 0.6326
# Epoch 2/10
# 11120/11120 [==============================] - 413s 37ms/step - loss: 0.9899 - product_output_loss: 0.0188 - subproduct_output_loss: 0.9711 - product_output_accuracy: 0.9902 - subproduct_output_accuracy: 0.6277 - val_loss: 0.9740 - val_product_output_loss: 0.0172 - val_subproduct_output_loss: 0.9568 - val_product_output_accuracy: 0.9908 - val_subproduct_output_accuracy: 0.6341
# Epoch 3/10
# 11120/11120 [==============================] - 431s 39ms/step - loss: 0.9863 - product_output_loss: 0.0184 - subproduct_output_loss: 0.9679 - product_output_accuracy: 0.9903 - subproduct_output_accuracy: 0.6280 - val_loss: 0.9759 - val_product_output_loss: 0.0179 - val_subproduct_output_loss: 0.9580 - val_product_output_accuracy: 0.9908 - val_subproduct_output_accuracy: 0.6327
# Epoch 4/10
# 11120/11120 [==============================] - 418s 38ms/step - loss: 0.9840 - product_output_loss: 0.0182 - subproduct_output_loss: 0.9658 - product_output_accuracy: 0.9903 - subproduct_output_accuracy: 0.6290 - val_loss: 0.9720 - val_product_output_loss: 0.0171 - val_subproduct_output_loss: 0.9549 - val_product_output_accuracy: 0.9908 - val_subproduct_output_accuracy: 0.6339
# Epoch 5/10
# 11120/11120 [==============================] - 452s 41ms/step - loss: 0.9827 - product_output_loss: 0.0182 - subproduct_output_loss: 0.9645 - product_output_accuracy: 0.9905 - subproduct_output_accuracy: 0.6292 - val_loss: 0.9727 - val_product_output_loss: 0.0172 - val_subproduct_output_loss: 0.9555 - val_product_output_accuracy: 0.9908 - val_subproduct_output_accuracy: 0.6340
# Epoch 6/10
# 11120/11120 [==============================] - 448s 40ms/step - loss: 0.9820 - product_output_loss: 0.0181 - subproduct_output_loss: 0.9639 - product_output_accuracy: 0.9905 - subproduct_output_accuracy: 0.6290 - val_loss: 0.9717 - val_product_output_loss: 0.0171 - val_subproduct_output_loss: 0.9547 - val_product_output_accuracy: 0.9908 - val_subproduct_output_accuracy: 0.6342
# Epoch 7/10
# 11120/11120 [==============================] - 449s 40ms/step - loss: 0.9816 - product_output_loss: 0.0180 - subproduct_output_loss: 0.9636 - product_output_accuracy: 0.9905 - subproduct_output_accuracy: 0.6292 - val_loss: 0.9722 - val_product_output_loss: 0.0171 - val_subproduct_output_loss: 0.9551 - val_product_output_accuracy: 0.9908 - val_subproduct_output_accuracy: 0.6329
# Epoch 8/10
# 11120/11120 [==============================] - 485s 44ms/step - loss: 0.9807 - product_output_loss: 0.0180 - subproduct_output_loss: 0.9628 - product_output_accuracy: 0.9906 - subproduct_output_accuracy: 0.6295 - val_loss: 0.9740 - val_product_output_loss: 0.0171 - val_subproduct_output_loss: 0.9569 - val_product_output_accuracy: 0.9908 - val_subproduct_output_accuracy: 0.6268
# Epoch 9/10
# 11120/11120 [==============================] - 455s 41ms/step - loss: 0.9806 - product_output_loss: 0.0180 - subproduct_output_loss: 0.9626 - product_output_accuracy: 0.9905 - subproduct_output_accuracy: 0.6297 - val_loss: 0.9701 - val_product_output_loss: 0.0170 - val_subproduct_output_loss: 0.9531 - val_product_output_accuracy: 0.9908 - val_subproduct_output_accuracy: 0.6338
# Epoch 10/10
# 11120/11120 [==============================] - 491s 44ms/step - loss: 0.9801 - product_output_loss: 0.0180 - subproduct_output_loss: 0.9622 - product_output_accuracy: 0.9906 - subproduct_output_accuracy: 0.6298 - val_loss: 0.9723 - val_product_output_loss: 0.0170 - val_subproduct_output_loss: 0.9553 - val_product_output_accuracy: 0.9908 - val_subproduct_output_accuracy: 0.6335

# %%
# 10. Evaluate
loss, prod_loss, subprod_loss, prod_acc, subprod_acc = model.evaluate(
    X_test, {'product_output': y_test_prod, 'subproduct_output': y_test_sub}
)

print(f"Product Accuracy: {prod_acc:.2f}")
print(f"Sub-Product Accuracy: {subprod_acc:.2f}")
# Out:
# 3475/3475 [==============================] - 38s 11ms/step - loss: 0.9751 - product_output_loss: 0.0175 - subproduct_output_loss: 0.9575 - product_output_accuracy: 0.9908 - subproduct_output_accuracy: 0.6316
# Product Accuracy: 0.99
# Sub-Product Accuracy: 0.63
